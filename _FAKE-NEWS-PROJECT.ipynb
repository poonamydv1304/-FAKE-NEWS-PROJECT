# %% [markdown]
# # FAKE-NEWS-PROJECT

# %%
# Importing the necessary libraries
import pandas as pd 
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import regexp_tokenize
from nltk.corpus import stopwords
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix, roc_curve, roc_auc_score

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.filterwarnings('ignore')

# %%
#getting fake data
os.chdir("C:\github_repo\Files")
fake_data = pd.read_csv("Fake.csv" , encoding='ISO-8859-1')

# %%
fake_data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Yearâ...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamaâs Na...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
fake_data.shape
# Out:
# (23481, 4)

# %%
fake_data.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
data=fake_data.iloc[:,0:4]
data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Yearâ...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamaâs Na...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
#Filling the missing values by fillna() method


data['subject']=data['subject'].fillna(data['subject'].mode()[0])
data['date']=data['date'].fillna(data['date'].mode()[0])

# %%
#Inserting one label column which take value zero as a fake news


data=data.assign(label=0)
data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Yearâ...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamaâs Na...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
#getting true dataset
os.chdir("C:\github_repo\Files")
true_data = pd.read_csv("True.csv" , encoding='ISO-8859-1')

# %%
true_data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
true_data.shape
# Out:
# (21417, 4)

# %%
true_data.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
#Inserting one label column which take value one as a true news
true_data=true_data.assign(label=1)
true_data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
#combining fake data and true data to make dataset
data=data.append(true_data,ignore_index=True)
data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Yearâ...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamaâs Na...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
data.shape
# Out:
# (44898, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   label    44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.7+ MB

# %% [markdown]
# ## DATA PREPROCESSING

# %%
# hetting lower case
data['title']=data['title'].str.lower()
data['text']=data['text'].str.lower()
data['subject']=data['subject'].str.lower()
data['date']=data['date'].str.lower()

# %%
# Removing numbers
data['title']=data['title'].replace(to_replace="[0-9]",value='', regex=True)
data['text']=data['text'].replace(to_replace="[0-9]",value='', regex=True)
data['subject']=data['subject'].replace(to_replace="[0-9]",value='', regex=True)
data['date']=data['date'].replace(to_replace="[0-9]",value='', regex=True)

# %%
# Removing symbols
data['title']=data['title'].replace(to_replace='[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]',value='', regex=True)
data['text']=data['text'].replace(to_replace='[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]',value='', regex=True)
data['subject']=data['subject'].replace(to_replace='[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]',value='', regex=True)
data['date']=data['date'].replace(to_replace='[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]',value='', regex=True)

# %%
# Removing stopwords
stop= stopwords.words('english')
data['title'] = data['title'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
data['text'] = data['text'].apply(lambda y: ' '.join([word for word in y.split() if word not in (stop)]))
data['subject'] = data['subject'].apply(lambda z: ' '.join([word for word in z.split() if word not in (stop)]))

# %%
data.head()
# Out:
#                                                title  \
# 0  donald trump sends embarrassing new yearâs e...
# 1  drunk bragging trump staffer started russian c...
# 2  sheriff david clarke becomes internet joke thr...
# 3  trump obsessed even obamaâs name coded websi...
# 4  pope francis called donald trump christmas speech
#
#                                                 text subject        date  \
# 0  donald trump wish americans happy new year lea...    news  december
# 1  house intelligence committee chairman devin nu...    news  december
# 2  friday revealed former milwaukee sheriff david...    news  december
# 3  christmas day donald trump announced would bac...    news  december
# 4  pope francis used annual christmas day message...    news  december
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %% [markdown]
# OBSERVATION
#
# All text in dataset is converted to lowecase and symbols are removed

# %% [markdown]
# ## DATA VISUALIZATION

# %%
data['subject'].value_counts()
# Out:
# politicsnews       11272
# worldnews          10145
# news                9050
# politics            6841
# leftnews            4459
# government news     1570
# usnews               783
# middleeast           778
# Name: subject, dtype: int64

# %%
data['subject']=data['subject'].replace(['news','politics'],['worldnews','politicsnews'])

# %%
ax= sns.countplot(x='subject',data=data)
print(data['subject'].value_counts())
# Out:
# worldnews          19195
# politicsnews       18113
# leftnews            4459
# government news     1570
# usnews               783
# middleeast           778
# Name: subject, dtype: int64

# %%
ax= sns.countplot(x='label',data=data)
print(data['label'].value_counts())
# Out:
# 0    23481
# 1    21417
# Name: label, dtype: int64

# %%
enc=OrdinalEncoder()

for i in data.columns:
    if data[i].dtypes=="object":
        data[i]=enc.fit_transform(data[i].values.reshape(-1,1))

# %% [markdown]
# ## DATA ANALYSIS

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  float64
#  1   text     44898 non-null  float64
#  2   subject  44898 non-null  float64
#  3   date     44898 non-null  float64
#  4   label    44898 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 1.7 MB

# %%
data.describe()
# Out:
#               title          text       subject          date         label
# count  44898.000000  44898.000000  44898.000000  44898.000000  44898.000000
# mean   19129.368791  18874.008530      3.551628     23.770569      0.477015
# std    11266.484150  11196.602614      1.467171     13.193514      0.499477
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     9365.000000   9337.250000      3.000000     10.000000      0.000000
# 50%    18912.500000  18870.500000      3.000000     27.000000      0.000000
# 75%    28839.750000  28302.000000      5.000000     35.000000      1.000000
# max    38676.000000  38636.000000      5.000000     41.000000      1.000000

# %% [markdown]
# ## CORRELATION

# %%
data.corr()
# Out:
#             title      text   subject      date     label
# title    1.000000  0.121418  0.015206 -0.005012  0.035420
# text     0.121418  1.000000 -0.115757 -0.023620  0.197835
# subject  0.015206 -0.115757  1.000000  0.153658  0.257612
# date    -0.005012 -0.023620  0.153658  1.000000  0.219934
# label    0.035420  0.197835  0.257612  0.219934  1.000000

# %%
plt.figure(figsize=(7,6))
sns.heatmap(data.corr(),annot=True,linewidth=0.5,linecolor='black')
# Out:
# <AxesSubplot:>

# %%
plt.scatter(data['label'],data['title'])
plt.xlabel('label')
plt.ylabel('title')
plt.show()

# %%
plt.scatter(data['label'],data['text'])
plt.xlabel('label')
plt.ylabel('text')
plt.show()

# %%
plt.scatter(data['label'],data['subject'])
plt.xlabel('label')
plt.ylabel('subject')
plt.show()

# %%
plt.scatter(data['label'],data['date'])
plt.xlabel('label')
plt.ylabel('date')
plt.show()

# %% [markdown]
# ## DATA MODELLING

# %%
x=data.drop(['label'],axis=1)
y=data['label']

# %% [markdown]
# ## Logistic Regression

# %%
lr=LogisticRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print("random state",i)
    print("Training accuracy score:",accuracy_score(y_train,pred_train)*100)
    print("Testing accuracy score:",accuracy_score(y_test,pred_test)*100)
    print('\n')
# Out:
# random state 0
# Training accuracy score: 56.3923889525264
# Testing accuracy score: 56.98589458054937
#
#
# random state 1
# Training accuracy score: 56.3892070764923
# Testing accuracy score: 56.919079435783225
#
#
# random state 2
# Training accuracy score: 56.63739340715286
# Testing accuracy score: 56.42167780252413
#
#
# random state 3
# Training accuracy score: 56.59284714267532
# Testing accuracy score: 56.42910170749814
#
#
# random state 4
# Training accuracy score: 56.513300241822584
# Testing accuracy score: 56.896807720861176
#
#
# random state 5
# Training accuracy score: 56.618302150948196
# Testing accuracy score: 56.666666666666664
#
#
# random state 6
# Training accuracy score: 56.360570192185314
# Testing accuracy score: 56.45137342242019
#
#
# random state 7
# Training accuracy score: 56.513300241822584
# Testing accuracy score: 55.93170007423905
#
#
# random state 8
# Training accuracy score: 56.39875270459462
# Testing accuracy score: 56.5924276169265
#
#
# random state 9
# Training accuracy score: 66.3134784268805
# Testing accuracy score: 66.36971046770601
#
#
# random state 10
# Training accuracy score: 56.53557337406134
# Testing accuracy score: 56.48106904231626
#
#
# random state 11
# Training accuracy score: 56.81239658902889
# Testing accuracy score: 55.96139569413512
#
#
# random state 12
# Training accuracy score: 56.70421280386916
# Testing accuracy score: 56.19153674832962
#
#
# random state 13
# Training accuracy score: 56.65012091128929
# Testing accuracy score: 56.30289532293986
#
#
# random state 14
# Training accuracy score: 56.732849688176145
# Testing accuracy score: 56.25835189309577
#
#
# random state 15
# Training accuracy score: 56.751940944380806
# Testing accuracy score: 56.495916852264294
#
#
# random state 16
# Training accuracy score: 56.87285223367697
# Testing accuracy score: 55.8203414996288
#
#
# random state 17
# Training accuracy score: 56.70739467990327
# Testing accuracy score: 56.31031922791389
#
#
# random state 18
# Training accuracy score: 56.71057655593737
# Testing accuracy score: 56.05048255382331
#
#
# random state 19
# Training accuracy score: 56.9460353824615
# Testing accuracy score: 56.02821083890126
#
#
# random state 20
# Training accuracy score: 56.49102710958381
# Testing accuracy score: 56.473645137342245
#
#
# random state 21
# Training accuracy score: 56.7487590683467
# Testing accuracy score: 56.221232368225685
#
#
# random state 22
# Training accuracy score: 56.54511900216368
# Testing accuracy score: 56.48849294729027
#
#
# random state 23
# Training accuracy score: 56.573755886470664
# Testing accuracy score: 56.644394951744616
#
#
# random state 24
# Training accuracy score: 56.806032836960675
# Testing accuracy score: 56.11729769858946
#
#
# random state 25
# Training accuracy score: 56.529209621993125
# Testing accuracy score: 56.56273199703043
#
#
# random state 26
# Training accuracy score: 56.513300241822584
# Testing accuracy score: 56.599851521900526
#
#
# random state 27
# Training accuracy score: 56.56102838233422
# Testing accuracy score: 56.45879732739421
#
#
# random state 28
# Training accuracy score: 56.40829833269696
# Testing accuracy score: 56.377134372680025
#
#
# random state 29
# Training accuracy score: 56.63421153111875
# Testing accuracy score: 56.473645137342245
#
#
# random state 30
# Training accuracy score: 56.58966526664121
# Testing accuracy score: 56.62212323682256
#
#
# random state 31
# Training accuracy score: 56.513300241822584
# Testing accuracy score: 56.243504083147734
#
#
# random state 32
# Training accuracy score: 56.246022654957365
# Testing accuracy score: 57.66889383815887
#
#
# random state 33
# Training accuracy score: 56.5864833906071
# Testing accuracy score: 56.807720861172974
#
#
# random state 34
# Training accuracy score: 56.68512154766451
# Testing accuracy score: 56.53303637713437
#
#
# random state 35
# Training accuracy score: 56.62784777905053
# Testing accuracy score: 56.42910170749814
#
#
# random state 36
# Training accuracy score: 56.61512027491409
# Testing accuracy score: 56.3177431328879
#
#
# random state 37
# Training accuracy score: 56.63102965508464
# Testing accuracy score: 56.25092798812176
#
#
# random state 38
# Training accuracy score: 56.46239022527683
# Testing accuracy score: 55.90200445434298
#
#
# random state 39
# Training accuracy score: 66.38984345169912
# Testing accuracy score: 65.9985152190052
#
#
# random state 40
# Training accuracy score: 56.379661448389975
# Testing accuracy score: 56.963622865627315
#
#
# random state 41
# Training accuracy score: 56.31602392770778
# Testing accuracy score: 56.97104677060134
#
#
# random state 42
# Training accuracy score: 56.510118365788465
# Testing accuracy score: 56.71863400148478
#
#
# random state 43
# Training accuracy score: 56.50693648975435
# Testing accuracy score: 56.770601336302896
#
#
# random state 44
# Training accuracy score: 56.494208985617924
# Testing accuracy score: 56.88195991091314
#
#
# random state 45
# Training accuracy score: 56.360570192185314
# Testing accuracy score: 56.919079435783225
#
#
# random state 46
# Training accuracy score: 56.60557464681176
# Testing accuracy score: 56.510764662212324
#
#
# random state 47
# Training accuracy score: 56.56739213440244
# Testing accuracy score: 56.78544914625093
#
#
# random state 48
# Training accuracy score: 56.79648720885835
# Testing accuracy score: 56.10987379361544
#
#
# random state 49
# Training accuracy score: 56.449662721140385
# Testing accuracy score: 56.94877505567929
#
#
# random state 50
# Training accuracy score: 56.548300878197786
# Testing accuracy score: 56.42167780252413
#
#
# random state 51
# Training accuracy score: 56.59284714267532
# Testing accuracy score: 56.84484038604306
#
#
# random state 52
# Training accuracy score: 56.50375461372025
# Testing accuracy score: 56.42910170749814
#
#
# random state 53
# Training accuracy score: 56.82830596919944
# Testing accuracy score: 56.03563474387527
#
#
# random state 54
# Training accuracy score: 56.47829960544737
# Testing accuracy score: 56.77802524127691
#
#
# random state 55
# Training accuracy score: 56.60557464681176
# Testing accuracy score: 56.71121009651077
#
#
# random state 56
# Training accuracy score: 56.825124093165336
# Testing accuracy score: 55.73867854491462
#
#
# random state 57
# Training accuracy score: 56.554664630266004
# Testing accuracy score: 56.599851521900526
#
#
# random state 58
# Training accuracy score: 56.43693521700395
# Testing accuracy score: 56.85968819599109
#
#
# random state 59
# Training accuracy score: 56.66921216749395
# Testing accuracy score: 56.29547141796585
#
#
# random state 60
# Training accuracy score: 56.60557464681176
# Testing accuracy score: 56.53303637713437
#
#
# random state 61
# Training accuracy score: 56.56739213440244
# Testing accuracy score: 56.60727542687454
#
#
# random state 62
# Training accuracy score: 56.602392770777655
# Testing accuracy score: 56.48849294729027
#
#
# random state 63
# Training accuracy score: 56.920580374188624
# Testing accuracy score: 56.13214550853749
#
#
# random state 64
# Training accuracy score: 56.5514827542319
# Testing accuracy score: 56.5924276169265
#
#
# random state 65
# Training accuracy score: 56.68512154766451
# Testing accuracy score: 56.273199703043794
#
#
# random state 66
# Training accuracy score: 56.62784777905053
# Testing accuracy score: 56.29547141796585
#
#
# random state 67
# Training accuracy score: 56.449662721140385
# Testing accuracy score: 56.78544914625093
#
#
# random state 68
# Training accuracy score: 56.68512154766451
# Testing accuracy score: 56.32516703786191
#
#
# random state 69
# Training accuracy score: 56.354206440117096
# Testing accuracy score: 56.84484038604306
#
#
# random state 70
# Training accuracy score: 56.49739086165203
# Testing accuracy score: 55.9985152190052
#
#
# random state 71
# Training accuracy score: 56.41784396079929
# Testing accuracy score: 56.88938381588715
#
#
# random state 72
# Training accuracy score: 56.43057146493573
# Testing accuracy score: 56.71121009651077
#
#
# random state 73
# Training accuracy score: 56.662848415425735
# Testing accuracy score: 56.228656273199704
#
#
# random state 74
# Training accuracy score: 56.6533027873234
# Testing accuracy score: 56.792873051224944
#
#
# random state 75
# Training accuracy score: 56.44648084510627
# Testing accuracy score: 56.55530809205642
#
#
# random state 76
# Training accuracy score: 56.414662084765176
# Testing accuracy score: 56.75575352635486
#
#
# random state 77
# Training accuracy score: 56.624665903016414
# Testing accuracy score: 56.16184112843355
#
#
# random state 78
# Training accuracy score: 56.421025836833394
# Testing accuracy score: 56.88938381588715
#
#
# random state 79
# Training accuracy score: 56.65012091128929
# Testing accuracy score: 56.62212323682256
#
#
# random state 80
# Training accuracy score: 56.716940308005604
# Testing accuracy score: 56.3177431328879
#
#
# random state 81
# Training accuracy score: 56.751940944380806
# Testing accuracy score: 56.23608017817372
#
#
# random state 82
# Training accuracy score: 56.618302150948196
# Testing accuracy score: 56.399406087602074
#
#
# random state 83
# Training accuracy score: 56.41784396079929
# Testing accuracy score: 56.770601336302896
#
#
# random state 84
# Training accuracy score: 56.4242077128675
# Testing accuracy score: 56.71121009651077
#
#
# random state 85
# Training accuracy score: 56.46239022527683
# Testing accuracy score: 56.807720861172974
#
#
# random state 86
# Training accuracy score: 56.08056510118365
# Testing accuracy score: 56.72605790645879
#
#
# random state 87
# Training accuracy score: 56.50693648975435
# Testing accuracy score: 56.71863400148478
#
#
# random state 88
# Training accuracy score: 56.61193839887998
# Testing accuracy score: 55.94654788418708
#
#
# random state 89
# Training accuracy score: 56.51648211785669
# Testing accuracy score: 56.763177431328884
#
#
# random state 90
# Training accuracy score: 56.57693776250478
# Testing accuracy score: 56.763177431328884
#
#
# random state 91
# Training accuracy score: 56.510118365788465
# Testing accuracy score: 56.75575352635486
#
#
# random state 92
# Training accuracy score: 56.529209621993125
# Testing accuracy score: 56.629547141796586
#
#
# random state 93
# Training accuracy score: 56.25556828305969
# Testing accuracy score: 56.503340757238306
#
#
# random state 94
# Training accuracy score: 56.69466717576683
# Testing accuracy score: 56.503340757238306
#
#
# random state 95
# Training accuracy score: 56.421025836833394
# Testing accuracy score: 56.1395694135115
#
#
# random state 96
# Training accuracy score: 56.414662084765176
# Testing accuracy score: 56.71121009651077
#
#
# random state 97
# Training accuracy score: 56.63102965508464
# Testing accuracy score: 56.09502598366741
#
#
# random state 98
# Training accuracy score: 56.42738958890162
# Testing accuracy score: 57.17149220489978
#
#
# random state 99
# Training accuracy score: 56.421025836833394
# Testing accuracy score: 56.00593912397921

# %%
#TRAIN TEST SPLIT
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.30,random_state=46)

# %%
lr.fit(x_train,y_train)
y_pred1 = lr.predict(x_test)
accuracy = accuracy_score(y_test,y_pred1)*100
print("accuracy score:",accuracy)
# Out:
# accuracy score: 56.510764662212324

# %%
cm= confusion_matrix(y_test,y_pred1)
print(cm)
# Out:
# [[3218 3727]
#  [2131 4394]]

# %%
clr=classification_report(y_test,y_pred1)
print(clr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.46      0.52      6945
#            1       0.54      0.67      0.60      6525
#
#     accuracy                           0.57     13470
#    macro avg       0.57      0.57      0.56     13470
# weighted avg       0.57      0.57      0.56     13470

# %%
# ROC_AUC CURVE
fpr,tpr,thresholds = roc_curve(y_test,y_pred1)

plt.plot(fpr,tpr,color='orange',label='Logistic Regression')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC_AUC curve')
plt.legend()                                                                                 
plt.show()

auc_score = roc_auc_score(y_test,y_pred1)*100
print("AUC_score",auc_score)
# Out:
# AUC_score 56.838244664564776

# %% [markdown]
# ## K Neighbors Classifier

# %%
knn= KNeighborsClassifier()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = i)
    knn.fit(x_train,y_train)
    pred_train=knn.predict(x_train)
    pred_test=knn.predict(x_test)
    print("random state",i)
    print("Training accuracy score:",accuracy_score(y_train,pred_train)*100)
    print("Testing accuracy score:",accuracy_score(y_test,pred_test)*100)
    print('\n')
# Out:
# random state 0
# Training accuracy score: 91.3548428153239
# Testing accuracy score: 87.1863400148478
#
#
# random state 1
# Training accuracy score: 91.22756777395952
# Testing accuracy score: 87.34966592427617
#
#
# random state 2
# Training accuracy score: 91.16711212931145
# Testing accuracy score: 87.1789161098738
#
#
# random state 3
# Training accuracy score: 91.27529591447117
# Testing accuracy score: 87.2234595397179
#
#
# random state 4
# Training accuracy score: 91.2498409061983
# Testing accuracy score: 87.07498144023756
#
#
# random state 5
# Training accuracy score: 91.2498409061983
# Testing accuracy score: 87.20118782479585
#
#
# random state 6
# Training accuracy score: 91.24029527809596
# Testing accuracy score: 87.27542687453601
#
#
# random state 7
# Training accuracy score: 91.33575155911926
# Testing accuracy score: 87.23088344469191
#
#
# random state 8
# Training accuracy score: 91.34211531118748
# Testing accuracy score: 87.00816629547143
#
#
# random state 9
# Training accuracy score: 91.16711212931145
# Testing accuracy score: 87.34966592427617
#
#
# random state 10
# Training accuracy score: 91.26893216240295
# Testing accuracy score: 87.16406829992576
#
#
# random state 11
# Training accuracy score: 91.2530227822324
# Testing accuracy score: 87.38678544914626
#
#
# random state 12
# Training accuracy score: 91.13529336897035
# Testing accuracy score: 87.62435040831478
#
#
# random state 13
# Training accuracy score: 91.43757159221076
# Testing accuracy score: 87.06013363028953
#
#
# random state 14
# Training accuracy score: 91.22120402189131
# Testing accuracy score: 87.14922048997774
#
#
# random state 15
# Training accuracy score: 91.29438717067583
# Testing accuracy score: 87.29769858945805
#
#
# random state 16
# Training accuracy score: 91.26575028636884
# Testing accuracy score: 86.74090571640683
#
#
# random state 17
# Training accuracy score: 91.27529591447117
# Testing accuracy score: 87.05270972531551
#
#
# random state 18
# Training accuracy score: 91.3834796996309
# Testing accuracy score: 87.1343726800297
#
#
# random state 19
# Training accuracy score: 91.27211403843705
# Testing accuracy score: 86.92650334075724
#
#
# random state 20
# Training accuracy score: 91.04301896398115
# Testing accuracy score: 87.14922048997774
#
#
# random state 21
# Training accuracy score: 91.35802469135803
# Testing accuracy score: 86.97847067557535
#
#
# random state 22
# Training accuracy score: 91.20211276568665
# Testing accuracy score: 86.97847067557535
#
#
# random state 23
# Training accuracy score: 91.45984472444954
# Testing accuracy score: 86.93392724573125
#
#
# random state 24
# Training accuracy score: 91.09711085656103
# Testing accuracy score: 87.37936154417223
#
#
# random state 25
# Training accuracy score: 91.3198421789487
# Testing accuracy score: 87.38678544914626
#
#
# random state 26
# Training accuracy score: 91.17983963344788
# Testing accuracy score: 87.28285077951003
#
#
# random state 27
# Training accuracy score: 91.41211658393789
# Testing accuracy score: 87.05270972531551
#
#
# random state 28
# Training accuracy score: 91.11620211276569
# Testing accuracy score: 87.4981440237565
#
#
# random state 29
# Training accuracy score: 91.3166603029146
# Testing accuracy score: 87.1789161098738
#
#
# random state 30
# Training accuracy score: 91.17665775741376
# Testing accuracy score: 87.01559020044543
#
#
# random state 31
# Training accuracy score: 91.16074837724322
# Testing accuracy score: 87.23088344469191
#
#
# random state 32
# Training accuracy score: 91.17029400534555
# Testing accuracy score: 87.0898292501856
#
#
# random state 33
# Training accuracy score: 91.23074964999364
# Testing accuracy score: 87.27542687453601
#
#
# random state 34
# Training accuracy score: 91.17029400534555
# Testing accuracy score: 87.6391982182628
#
#
# random state 35
# Training accuracy score: 91.23393152602775
# Testing accuracy score: 86.99331848552339
#
#
# random state 36
# Training accuracy score: 91.20847651775486
# Testing accuracy score: 87.10467706013362
#
#
# random state 37
# Training accuracy score: 91.06847397225404
# Testing accuracy score: 87.03043801039347
#
#
# random state 38
# Training accuracy score: 91.33256968308515
# Testing accuracy score: 87.26057906458797
#
#
# random state 39
# Training accuracy score: 91.2530227822324
# Testing accuracy score: 87.41648106904232
#
#
# random state 40
# Training accuracy score: 91.10665648466336
# Testing accuracy score: 87.33481811432814
#
#
# random state 41
# Training accuracy score: 91.38029782359679
# Testing accuracy score: 87.14179658500372
#
#
# random state 42
# Training accuracy score: 90.98256331933308
# Testing accuracy score: 87.3199703043801
#
#
# random state 43
# Training accuracy score: 91.04620084001527
# Testing accuracy score: 87.17149220489978
#
#
# random state 44
# Training accuracy score: 91.45666284841542
# Testing accuracy score: 86.71863400148479
#
#
# random state 45
# Training accuracy score: 91.3548428153239
# Testing accuracy score: 87.02301410541945
#
#
# random state 46
# Training accuracy score: 91.14165712103856
# Testing accuracy score: 87.21603563474387
#
#
# random state 47
# Training accuracy score: 91.41211658393789
# Testing accuracy score: 86.83741648106904
#
#
# random state 48
# Training accuracy score: 91.25938653430062
# Testing accuracy score: 87.23830734966592
#
#
# random state 49
# Training accuracy score: 91.08120147639049
# Testing accuracy score: 87.0452858203415
#
#
# random state 50
# Training accuracy score: 91.20211276568665
# Testing accuracy score: 87.14179658500372
#
#
# random state 51
# Training accuracy score: 91.3166603029146
# Testing accuracy score: 87.53526354862657
#
#
# random state 52
# Training accuracy score: 91.09711085656103
# Testing accuracy score: 87.14922048997774
#
#
# random state 53
# Training accuracy score: 91.36757031946036
# Testing accuracy score: 87.10467706013362
#
#
# random state 54
# Training accuracy score: 91.36438844342625
# Testing accuracy score: 87.06013363028953
#
#
# random state 55
# Training accuracy score: 91.29120529464171
# Testing accuracy score: 87.11210096510764
#
#
# random state 56
# Training accuracy score: 91.05892834415171
# Testing accuracy score: 87.75055679287304
#
#
# random state 57
# Training accuracy score: 91.41848033600611
# Testing accuracy score: 86.6815144766147
#
#
# random state 58
# Training accuracy score: 91.19574901361844
# Testing accuracy score: 87.4090571640683
#
#
# random state 59
# Training accuracy score: 91.24347715413008
# Testing accuracy score: 86.7706013363029
#
#
# random state 60
# Training accuracy score: 91.1225658648339
# Testing accuracy score: 87.4536005939124
#
#
# random state 61
# Training accuracy score: 91.2466590301642
# Testing accuracy score: 86.79287305122494
#
#
# random state 62
# Training accuracy score: 91.3548428153239
# Testing accuracy score: 87.0898292501856
#
#
# random state 63
# Training accuracy score: 91.01120020364006
# Testing accuracy score: 87.3199703043801
#
#
# random state 64
# Training accuracy score: 91.33575155911926
# Testing accuracy score: 86.76317743132887
#
#
# random state 65
# Training accuracy score: 91.04620084001527
# Testing accuracy score: 87.42390497401632
#
#
# random state 66
# Training accuracy score: 91.27847779050529
# Testing accuracy score: 87.06013363028953
#
#
# random state 67
# Training accuracy score: 91.45029909634721
# Testing accuracy score: 86.89680772086118
#
#
# random state 68
# Training accuracy score: 91.24347715413008
# Testing accuracy score: 87.21603563474387
#
#
# random state 69
# Training accuracy score: 91.43757159221076
# Testing accuracy score: 87.46102449888642
#
#
# random state 70
# Training accuracy score: 91.43120784014255
# Testing accuracy score: 87.1343726800297
#
#
# random state 71
# Training accuracy score: 91.20529464172076
# Testing accuracy score: 87.32739420935413
#
#
# random state 72
# Training accuracy score: 91.22120402189131
# Testing accuracy score: 87.1789161098738
#
#
# random state 73
# Training accuracy score: 91.07165584828815
# Testing accuracy score: 87.71343726800296
#
#
# random state 74
# Training accuracy score: 91.20847651775486
# Testing accuracy score: 87.26057906458797
#
#
# random state 75
# Training accuracy score: 91.5807560137457
# Testing accuracy score: 87.0452858203415
#
#
# random state 76
# Training accuracy score: 91.37711594756269
# Testing accuracy score: 87.48329621380846
#
#
# random state 77
# Training accuracy score: 91.31029655084639
# Testing accuracy score: 87.21603563474387
#
#
# random state 78
# Training accuracy score: 91.29120529464171
# Testing accuracy score: 87.0452858203415
#
#
# random state 79
# Training accuracy score: 91.34211531118748
# Testing accuracy score: 87.03043801039347
#
#
# random state 80
# Training accuracy score: 91.2816596665394
# Testing accuracy score: 87.28285077951003
#
#
# random state 81
# Training accuracy score: 91.25938653430062
# Testing accuracy score: 87.37193763919822
#
#
# random state 82
# Training accuracy score: 91.386661575665
# Testing accuracy score: 87.10467706013362
#
#
# random state 83
# Training accuracy score: 91.3166603029146
# Testing accuracy score: 87.23088344469191
#
#
# random state 84
# Training accuracy score: 91.14802087310679
# Testing accuracy score: 87.34224201930215
#
#
# random state 85
# Training accuracy score: 91.19256713758432
# Testing accuracy score: 87.08240534521158
#
#
# random state 86
# Training accuracy score: 91.10347460862924
# Testing accuracy score: 86.80772086117298
#
#
# random state 87
# Training accuracy score: 91.17665775741376
# Testing accuracy score: 87.10467706013362
#
#
# random state 88
# Training accuracy score: 91.28802341860761
# Testing accuracy score: 87.31254639940609
#
#
# random state 89
# Training accuracy score: 91.29438717067583
# Testing accuracy score: 87.23830734966592
#
#
# random state 90
# Training accuracy score: 91.0843833524246
# Testing accuracy score: 87.02301410541945
#
#
# random state 91
# Training accuracy score: 91.40575283186966
# Testing accuracy score: 87.29027468448403
#
#
# random state 92
# Training accuracy score: 91.10029273259514
# Testing accuracy score: 87.26057906458797
#
#
# random state 93
# Training accuracy score: 91.16711212931145
# Testing accuracy score: 86.43652561247215
#
#
# random state 94
# Training accuracy score: 91.154384625175
# Testing accuracy score: 87.01559020044543
#
#
# random state 95
# Training accuracy score: 91.25620465826651
# Testing accuracy score: 87.42390497401632
#
#
# random state 96
# Training accuracy score: 91.37075219549446
# Testing accuracy score: 87.06755753526355
#
#
# random state 97
# Training accuracy score: 91.22438589792542
# Testing accuracy score: 87.37193763919822
#
#
# random state 98
# Training accuracy score: 91.28802341860761
# Testing accuracy score: 86.83741648106904
#
#
# random state 99
# Training accuracy score: 91.3484790632557
# Testing accuracy score: 87.05270972531551

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=68)

# %%
knn.fit(x_train,y_train)
y_pred2 = knn.predict(x_test)
accuracy = accuracy_score(y_test,y_pred2)*100
print("accuracy score:",accuracy)
# Out:
# accuracy score: 87.21603563474387

# %%
#CONFUSION MATRIX
cm= confusion_matrix(y_test,y_pred2)
print(cm)
# Out:
# [[6337  653]
#  [1069 5411]]

# %%
clr=classification_report(y_test,y_pred2)
print(clr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      6990
#            1       0.89      0.84      0.86      6480
#
#     accuracy                           0.87     13470
#    macro avg       0.87      0.87      0.87     13470
# weighted avg       0.87      0.87      0.87     13470

# %%
#ROC_AUC FOR K NEIGHBORS
fpr,tpr,thresholds = roc_curve(y_test,y_pred2)

plt.plot(fpr,tpr,color='orange',label='K Neighbors Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC_AUC curve')
plt.legend()                                                                                 
plt.show()

auc_score = roc_auc_score(y_test,y_pred2)*100
print("AUC_score",auc_score)
# Out:
# AUC_score 87.08058469771632

# %% [markdown]
# ## Random Forest Classifier

# %%
rfc=RandomForestClassifier()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = i)
    rfc.fit(x_train,y_train)
    pred_train=rfc.predict(x_train)
    pred_test=rfc.predict(x_test)
    print("random state",i)
    print("Training accuracy score:",accuracy_score(y_train,pred_train)*100)
    print("Testing accuracy score:",accuracy_score(y_test,pred_test)*100)
    print('\n')
# Out:
# random state 0
# Training accuracy score: 100.0
# Testing accuracy score: 99.45805493689681
#
#
# random state 1
# Training accuracy score: 100.0
# Testing accuracy score: 99.47290274684484
#
#
# random state 2
# Training accuracy score: 100.0
# Testing accuracy score: 99.57683741648107
#
#
# random state 3
# Training accuracy score: 100.0
# Testing accuracy score: 99.42835931700074
#
#
# random state 4
# Training accuracy score: 100.0
# Testing accuracy score: 99.51002227171493
#
#
# random state 5
# Training accuracy score: 100.0
# Testing accuracy score: 99.55456570155901
#
#
# random state 6
# Training accuracy score: 100.0
# Testing accuracy score: 99.56941351150705
#
#
# random state 7
# Training accuracy score: 100.0
# Testing accuracy score: 99.4951744617669
#
#
# random state 8
# Training accuracy score: 100.0
# Testing accuracy score: 99.53971789161099
#
#
# random state 9
# Training accuracy score: 100.0
# Testing accuracy score: 99.59910913140313
#
#
# random state 10
# Training accuracy score: 100.0
# Testing accuracy score: 99.45805493689681
#
#
# random state 11
# Training accuracy score: 100.0
# Testing accuracy score: 99.59910913140313
#
#
# random state 12
# Training accuracy score: 100.0
# Testing accuracy score: 99.46547884187082
#
#
# random state 13
# Training accuracy score: 100.0
# Testing accuracy score: 99.48775055679288
#
#
# random state 14
# Training accuracy score: 100.0
# Testing accuracy score: 99.54714179658501
#
#
# random state 15
# Training accuracy score: 100.0
# Testing accuracy score: 99.58426132145507
#
#
# random state 16
# Training accuracy score: 100.0
# Testing accuracy score: 99.5025983667409
#
#
# random state 17
# Training accuracy score: 100.0
# Testing accuracy score: 99.57683741648107
#
#
# random state 18
# Training accuracy score: 100.0
# Testing accuracy score: 99.57683741648107
#
#
# random state 19
# Training accuracy score: 100.0
# Testing accuracy score: 99.48032665181886
#
#
# random state 20
# Training accuracy score: 100.0
# Testing accuracy score: 99.53971789161099
#
#
# random state 21
# Training accuracy score: 100.0
# Testing accuracy score: 99.31700074239049
#
#
# random state 22
# Training accuracy score: 100.0
# Testing accuracy score: 99.45063103192278
#
#
# random state 23
# Training accuracy score: 100.0
# Testing accuracy score: 99.5916852264291
#
#
# random state 24
# Training accuracy score: 100.0
# Testing accuracy score: 99.56941351150705
#
#
# random state 25
# Training accuracy score: 100.0
# Testing accuracy score: 99.45063103192278
#
#
# random state 26
# Training accuracy score: 100.0
# Testing accuracy score: 99.53971789161099
#
#
# random state 27
# Training accuracy score: 100.0
# Testing accuracy score: 99.53971789161099
#
#
# random state 28
# Training accuracy score: 100.0
# Testing accuracy score: 99.53971789161099
#
#
# random state 29
# Training accuracy score: 100.0
# Testing accuracy score: 99.58426132145507
#
#
# random state 30
# Training accuracy score: 100.0
# Testing accuracy score: 99.47290274684484
#
#
# random state 31
# Training accuracy score: 100.0
# Testing accuracy score: 99.55456570155901
#
#
# random state 32
# Training accuracy score: 100.0
# Testing accuracy score: 99.45805493689681
#
#
# random state 33
# Training accuracy score: 100.0
# Testing accuracy score: 99.5025983667409
#
#
# random state 34
# Training accuracy score: 100.0
# Testing accuracy score: 99.4951744617669
#
#
# random state 35
# Training accuracy score: 100.0
# Testing accuracy score: 99.65107646622123
#
#
# random state 36
# Training accuracy score: 100.0
# Testing accuracy score: 99.51744617668894
#
#
# random state 37
# Training accuracy score: 100.0
# Testing accuracy score: 99.57683741648107
#
#
# random state 38
# Training accuracy score: 100.0
# Testing accuracy score: 99.5916852264291
#
#
# random state 39
# Training accuracy score: 100.0
# Testing accuracy score: 99.56198960653305
#
#
# random state 40
# Training accuracy score: 100.0
# Testing accuracy score: 99.5916852264291
#
#
# random state 41
# Training accuracy score: 100.0
# Testing accuracy score: 99.5916852264291
#
#
# random state 42
# Training accuracy score: 100.0
# Testing accuracy score: 99.56198960653305
#
#
# random state 43
# Training accuracy score: 100.0
# Testing accuracy score: 99.5025983667409
#
#
# random state 44
# Training accuracy score: 100.0
# Testing accuracy score: 99.51744617668894
#
#
# random state 45
# Training accuracy score: 100.0
# Testing accuracy score: 99.56941351150705
#
#
# random state 46
# Training accuracy score: 100.0
# Testing accuracy score: 99.5916852264291
#
#
# random state 47
# Training accuracy score: 100.0
# Testing accuracy score: 99.5025983667409
#
#
# random state 48
# Training accuracy score: 100.0
# Testing accuracy score: 99.48032665181886
#
#
# random state 49
# Training accuracy score: 100.0
# Testing accuracy score: 99.52487008166295
#
#
# random state 50
# Training accuracy score: 100.0
# Testing accuracy score: 99.45063103192278
#
#
# random state 51
# Training accuracy score: 100.0
# Testing accuracy score: 99.5025983667409
#
#
# random state 52
# Training accuracy score: 100.0
# Testing accuracy score: 99.45805493689681
#
#
# random state 53
# Training accuracy score: 100.0
# Testing accuracy score: 99.4135115070527
#
#
# random state 54
# Training accuracy score: 100.0
# Testing accuracy score: 99.48775055679288
#
#
# random state 55
# Training accuracy score: 100.0
# Testing accuracy score: 99.58426132145507
#
#
# random state 56
# Training accuracy score: 100.0
# Testing accuracy score: 99.61395694135116
#
#
# random state 57
# Training accuracy score: 100.0
# Testing accuracy score: 99.61395694135116
#
#
# random state 58
# Training accuracy score: 100.0
# Testing accuracy score: 99.59910913140313
#
#
# random state 59
# Training accuracy score: 100.0
# Testing accuracy score: 99.54714179658501
#
#
# random state 60
# Training accuracy score: 100.0
# Testing accuracy score: 99.53971789161099
#
#
# random state 61
# Training accuracy score: 100.0
# Testing accuracy score: 99.56941351150705
#
#
# random state 62
# Training accuracy score: 100.0
# Testing accuracy score: 99.48032665181886
#
#
# random state 63
# Training accuracy score: 100.0
# Testing accuracy score: 99.53229398663697
#
#
# random state 64
# Training accuracy score: 100.0
# Testing accuracy score: 99.51744617668894
#
#
# random state 65
# Training accuracy score: 100.0
# Testing accuracy score: 99.51002227171493
#
#
# random state 66
# Training accuracy score: 100.0
# Testing accuracy score: 99.60653303637713
#
#
# random state 67
# Training accuracy score: 100.0
# Testing accuracy score: 99.52487008166295
#
#
# random state 68
# Training accuracy score: 100.0
# Testing accuracy score: 99.59910913140313
#
#
# random state 69
# Training accuracy score: 100.0
# Testing accuracy score: 99.62880475129919
#
#
# random state 70
# Training accuracy score: 100.0
# Testing accuracy score: 99.45063103192278
#
#
# random state 71
# Training accuracy score: 100.0
# Testing accuracy score: 99.70304380103934
#
#
# random state 72
# Training accuracy score: 100.0
# Testing accuracy score: 99.61395694135116
#
#
# random state 73
# Training accuracy score: 100.0
# Testing accuracy score: 99.4951744617669
#
#
# random state 74
# Training accuracy score: 100.0
# Testing accuracy score: 99.61395694135116
#
#
# random state 75
# Training accuracy score: 100.0
# Testing accuracy score: 99.45063103192278
#
#
# random state 76
# Training accuracy score: 100.0
# Testing accuracy score: 99.4060876020787
#
#
# random state 77
# Training accuracy score: 100.0
# Testing accuracy score: 99.63622865627319
#
#
# random state 78
# Training accuracy score: 100.0
# Testing accuracy score: 99.62880475129919
#
#
# random state 79
# Training accuracy score: 100.0
# Testing accuracy score: 99.48032665181886
#
#
# random state 80
# Training accuracy score: 100.0
# Testing accuracy score: 99.58426132145507
#
#
# random state 81
# Training accuracy score: 100.0
# Testing accuracy score: 99.51002227171493
#
#
# random state 82
# Training accuracy score: 100.0
# Testing accuracy score: 99.57683741648107
#
#
# random state 83
# Training accuracy score: 100.0
# Testing accuracy score: 99.51744617668894
#
#
# random state 84
# Training accuracy score: 100.0
# Testing accuracy score: 99.5916852264291
#
#
# random state 85
# Training accuracy score: 100.0
# Testing accuracy score: 99.63622865627319
#
#
# random state 86
# Training accuracy score: 100.0
# Testing accuracy score: 99.63622865627319
#
#
# random state 87
# Training accuracy score: 100.0
# Testing accuracy score: 99.46547884187082
#
#
# random state 88
# Training accuracy score: 100.0
# Testing accuracy score: 99.5025983667409
#
#
# random state 89
# Training accuracy score: 100.0
# Testing accuracy score: 99.52487008166295
#
#
# random state 90
# Training accuracy score: 100.0
# Testing accuracy score: 99.45063103192278
#
#
# random state 91
# Training accuracy score: 100.0
# Testing accuracy score: 99.54714179658501
#
#
# random state 92
# Training accuracy score: 100.0
# Testing accuracy score: 99.56941351150705
#
#
# random state 93
# Training accuracy score: 100.0
# Testing accuracy score: 99.53229398663697
#
#
# random state 94
# Training accuracy score: 100.0
# Testing accuracy score: 99.31700074239049
#
#
# random state 95
# Training accuracy score: 100.0
# Testing accuracy score: 99.48775055679288
#
#
# random state 96
# Training accuracy score: 100.0
# Testing accuracy score: 99.51002227171493
#
#
# random state 97
# Training accuracy score: 100.0
# Testing accuracy score: 99.60653303637713
#
#
# random state 98
# Training accuracy score: 100.0
# Testing accuracy score: 99.58426132145507
#
#
# random state 99
# Training accuracy score: 100.0
# Testing accuracy score: 99.54714179658501

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.30,random_state=93)

# %%
rfc.fit(x_train,y_train)
y_pred3 = rfc.predict(x_test)
accuracy = accuracy_score(y_test,y_pred3)*100
print("accuracy score:",accuracy)
# Out:
# accuracy score: 99.4951744617669

# %%
cm= confusion_matrix(y_test,y_pred3)
print(cm)
# Out:
# [[7027   17]
#  [  51 6375]]

# %%
clr=classification_report(y_test,y_pred3)
print(clr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7044
#            1       1.00      0.99      0.99      6426
#
#     accuracy                           0.99     13470
#    macro avg       1.00      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
fpr,tpr,thresholds = roc_curve(y_test,y_pred3)

plt.plot(fpr,tpr,color='orange',label='Random Forest Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC_AUC curve')
plt.legend()                                                                                 
plt.show()

auc_score = roc_auc_score(y_test,y_pred3)*100
print("AUC_score",auc_score)
# Out:
# AUC_score 99.48250452935291

# %% [markdown]
# ## Decision Tree Classifier

# %%
clf=DecisionTreeClassifier()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = i)
    clf.fit(x_train,y_train)
    pred_train=clf.predict(x_train)
    pred_test=clf.predict(x_test)
    print("random state",i)
    print("Training accuracy score:",accuracy_score(y_train,pred_train)*100)
    print("Testing accuracy score:",accuracy_score(y_test,pred_test)*100)
    print('\n')
# Out:
# random state 0
# Training accuracy score: 100.0
# Testing accuracy score: 99.92576095025983
#
#
# random state 1
# Training accuracy score: 100.0
# Testing accuracy score: 99.85152190051967
#
#
# random state 2
# Training accuracy score: 100.0
# Testing accuracy score: 99.91833704528582
#
#
# random state 3
# Training accuracy score: 100.0
# Testing accuracy score: 99.93318485523385
#
#
# random state 4
# Training accuracy score: 100.0
# Testing accuracy score: 99.92576095025983
#
#
# random state 5
# Training accuracy score: 100.0
# Testing accuracy score: 99.97030438010394
#
#
# random state 6
# Training accuracy score: 100.0
# Testing accuracy score: 99.91833704528582
#
#
# random state 7
# Training accuracy score: 100.0
# Testing accuracy score: 99.94803266518188
#
#
# random state 8
# Training accuracy score: 100.0
# Testing accuracy score: 99.9109131403118
#
#
# random state 9
# Training accuracy score: 100.0
# Testing accuracy score: 99.85894580549369
#
#
# random state 10
# Training accuracy score: 100.0
# Testing accuracy score: 99.90348923533779
#
#
# random state 11
# Training accuracy score: 100.0
# Testing accuracy score: 99.92576095025983
#
#
# random state 12
# Training accuracy score: 100.0
# Testing accuracy score: 99.88864142538975
#
#
# random state 13
# Training accuracy score: 100.0
# Testing accuracy score: 99.86636971046771
#
#
# random state 14
# Training accuracy score: 100.0
# Testing accuracy score: 99.93318485523385
#
#
# random state 15
# Training accuracy score: 100.0
# Testing accuracy score: 99.90348923533779
#
#
# random state 16
# Training accuracy score: 100.0
# Testing accuracy score: 99.9109131403118
#
#
# random state 17
# Training accuracy score: 100.0
# Testing accuracy score: 99.92576095025983
#
#
# random state 18
# Training accuracy score: 100.0
# Testing accuracy score: 99.91833704528582
#
#
# random state 19
# Training accuracy score: 100.0
# Testing accuracy score: 99.88864142538975
#
#
# random state 20
# Training accuracy score: 100.0
# Testing accuracy score: 99.84409799554565
#
#
# random state 21
# Training accuracy score: 100.0
# Testing accuracy score: 99.94803266518188
#
#
# random state 22
# Training accuracy score: 100.0
# Testing accuracy score: 99.92576095025983
#
#
# random state 23
# Training accuracy score: 100.0
# Testing accuracy score: 99.92576095025983
#
#
# random state 24
# Training accuracy score: 100.0
# Testing accuracy score: 99.92576095025983
#
#
# random state 25
# Training accuracy score: 100.0
# Testing accuracy score: 99.94060876020787
#
#
# random state 26
# Training accuracy score: 100.0
# Testing accuracy score: 99.90348923533779
#
#
# random state 27
# Training accuracy score: 100.0
# Testing accuracy score: 99.86636971046771
#
#
# random state 28
# Training accuracy score: 100.0
# Testing accuracy score: 99.86636971046771
#
#
# random state 29
# Training accuracy score: 100.0
# Testing accuracy score: 99.94060876020787
#
#
# random state 30
# Training accuracy score: 100.0
# Testing accuracy score: 99.88864142538975
#
#
# random state 31
# Training accuracy score: 100.0
# Testing accuracy score: 99.90348923533779
#
#
# random state 32
# Training accuracy score: 100.0
# Testing accuracy score: 99.85894580549369
#
#
# random state 33
# Training accuracy score: 100.0
# Testing accuracy score: 99.93318485523385
#
#
# random state 34
# Training accuracy score: 100.0
# Testing accuracy score: 99.88864142538975
#
#
# random state 35
# Training accuracy score: 100.0
# Testing accuracy score: 99.90348923533779
#
#
# random state 36
# Training accuracy score: 100.0
# Testing accuracy score: 99.88121752041575
#
#
# random state 37
# Training accuracy score: 100.0
# Testing accuracy score: 99.86636971046771
#
#
# random state 38
# Training accuracy score: 100.0
# Testing accuracy score: 99.89606533036377
#
#
# random state 39
# Training accuracy score: 100.0
# Testing accuracy score: 99.90348923533779
#
#
# random state 40
# Training accuracy score: 100.0
# Testing accuracy score: 99.94803266518188
#
#
# random state 41
# Training accuracy score: 100.0
# Testing accuracy score: 99.88864142538975
#
#
# random state 42
# Training accuracy score: 100.0
# Testing accuracy score: 99.89606533036377
#
#
# random state 43
# Training accuracy score: 100.0
# Testing accuracy score: 99.94060876020787
#
#
# random state 44
# Training accuracy score: 100.0
# Testing accuracy score: 99.84409799554565
#
#
# random state 45
# Training accuracy score: 100.0
# Testing accuracy score: 99.93318485523385
#
#
# random state 46
# Training accuracy score: 100.0
# Testing accuracy score: 99.96288047512992
#
#
# random state 47
# Training accuracy score: 100.0
# Testing accuracy score: 99.94803266518188
#
#
# random state 48
# Training accuracy score: 100.0
# Testing accuracy score: 99.85152190051967
#
#
# random state 49
# Training accuracy score: 100.0
# Testing accuracy score: 99.87379361544171
#
#
# random state 50
# Training accuracy score: 100.0
# Testing accuracy score: 99.88864142538975
#
#
# random state 51
# Training accuracy score: 100.0
# Testing accuracy score: 99.87379361544171
#
#
# random state 52
# Training accuracy score: 100.0
# Testing accuracy score: 99.9109131403118
#
#
# random state 53
# Training accuracy score: 100.0
# Testing accuracy score: 99.90348923533779
#
#
# random state 54
# Training accuracy score: 100.0
# Testing accuracy score: 99.85152190051967
#
#
# random state 55
# Training accuracy score: 100.0
# Testing accuracy score: 99.89606533036377
#
#
# random state 56
# Training accuracy score: 100.0
# Testing accuracy score: 99.89606533036377
#
#
# random state 57
# Training accuracy score: 100.0
# Testing accuracy score: 99.91833704528582
#
#
# random state 58
# Training accuracy score: 100.0
# Testing accuracy score: 99.93318485523385
#
#
# random state 59
# Training accuracy score: 100.0
# Testing accuracy score: 99.9554565701559
#
#
# random state 60
# Training accuracy score: 100.0
# Testing accuracy score: 99.88121752041575
#
#
# random state 61
# Training accuracy score: 100.0
# Testing accuracy score: 99.90348923533779
#
#
# random state 62
# Training accuracy score: 100.0
# Testing accuracy score: 99.85894580549369
#
#
# random state 63
# Training accuracy score: 100.0
# Testing accuracy score: 99.91833704528582
#
#
# random state 64
# Training accuracy score: 100.0
# Testing accuracy score: 99.9109131403118
#
#
# random state 65
# Training accuracy score: 100.0
# Testing accuracy score: 99.9109131403118
#
#
# random state 66
# Training accuracy score: 100.0
# Testing accuracy score: 99.89606533036377
#
#
# random state 67
# Training accuracy score: 100.0
# Testing accuracy score: 99.82925018559763
#
#
# random state 68
# Training accuracy score: 100.0
# Testing accuracy score: 99.94060876020787
#
#
# random state 69
# Training accuracy score: 100.0
# Testing accuracy score: 99.92576095025983
#
#
# random state 70
# Training accuracy score: 100.0
# Testing accuracy score: 99.88864142538975
#
#
# random state 71
# Training accuracy score: 100.0
# Testing accuracy score: 99.9109131403118
#
#
# random state 72
# Training accuracy score: 100.0
# Testing accuracy score: 99.88121752041575
#
#
# random state 73
# Training accuracy score: 100.0
# Testing accuracy score: 99.89606533036377
#
#
# random state 74
# Training accuracy score: 100.0
# Testing accuracy score: 99.85894580549369
#
#
# random state 75
# Training accuracy score: 100.0
# Testing accuracy score: 99.93318485523385
#
#
# random state 76
# Training accuracy score: 100.0
# Testing accuracy score: 99.89606533036377
#
#
# random state 77
# Training accuracy score: 100.0
# Testing accuracy score: 99.88121752041575
#
#
# random state 78
# Training accuracy score: 100.0
# Testing accuracy score: 99.9109131403118
#
#
# random state 79
# Training accuracy score: 100.0
# Testing accuracy score: 99.94060876020787
#
#
# random state 80
# Training accuracy score: 100.0
# Testing accuracy score: 99.9554565701559
#
#
# random state 81
# Training accuracy score: 100.0
# Testing accuracy score: 99.93318485523385
#
#
# random state 82
# Training accuracy score: 100.0
# Testing accuracy score: 99.91833704528582
#
#
# random state 83
# Training accuracy score: 100.0
# Testing accuracy score: 99.91833704528582
#
#
# random state 84
# Training accuracy score: 100.0
# Testing accuracy score: 99.91833704528582
#
#
# random state 85
# Training accuracy score: 100.0
# Testing accuracy score: 99.9109131403118
#
#
# random state 86
# Training accuracy score: 100.0
# Testing accuracy score: 99.88121752041575
#
#
# random state 87
# Training accuracy score: 100.0
# Testing accuracy score: 99.94803266518188
#
#
# random state 88
# Training accuracy score: 100.0
# Testing accuracy score: 99.90348923533779
#
#
# random state 89
# Training accuracy score: 100.0
# Testing accuracy score: 99.91833704528582
#
#
# random state 90
# Training accuracy score: 100.0
# Testing accuracy score: 99.90348923533779
#
#
# random state 91
# Training accuracy score: 100.0
# Testing accuracy score: 99.94060876020787
#
#
# random state 92
# Training accuracy score: 100.0
# Testing accuracy score: 99.89606533036377
#
#
# random state 93
# Training accuracy score: 100.0
# Testing accuracy score: 99.88864142538975
#
#
# random state 94
# Training accuracy score: 100.0
# Testing accuracy score: 99.84409799554565
#
#
# random state 95
# Training accuracy score: 100.0
# Testing accuracy score: 99.89606533036377
#
#
# random state 96
# Training accuracy score: 100.0
# Testing accuracy score: 99.93318485523385
#
#
# random state 97
# Training accuracy score: 100.0
# Testing accuracy score: 99.9554565701559
#
#
# random state 98
# Training accuracy score: 100.0
# Testing accuracy score: 99.88121752041575
#
#
# random state 99
# Training accuracy score: 100.0
# Testing accuracy score: 99.87379361544171

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.30,random_state=40)

# %%
clf.fit(x_train,y_train)
y_pred4 = clf.predict(x_test)
accuracy = accuracy_score(y_test,y_pred4)*100
print("accuracy score:",accuracy)
# Out:
# accuracy score: 99.94803266518188

# %%
cm= confusion_matrix(y_test,y_pred4)
print(cm)
# Out:
# [[7001    4]
#  [   3 6462]]

# %%
clr=classification_report(y_test,y_pred4)
print(clr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7005
#            1       1.00      1.00      1.00      6465
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
fpr,tpr,thresholds = roc_curve(y_test,y_pred4)

plt.plot(fpr,tpr,color='orange',label='Decision Tree Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC_AUC curve')
plt.legend()                                                                                 
plt.show()

auc_score = roc_auc_score(y_test,y_pred4)*100
print("AUC_score",auc_score)
# Out:
# AUC_score 99.9482471088765

# %% [markdown]
# ### OBSERVATION
#
#
# Decision Tree Classifier predicts better result for this problem, so we consider this model as a best model. Accuracy score is good thats why we do not require to tune the parameters.

# %% [markdown]
# ## SAVING FILE

# %%
import joblib
joblib.dump(y_pred4,"Fake_News_Project.pkl")
# Out:
# ['Fake_News_Project.pkl']

# %% [markdown]
# ## CONCLUSION

# %%
Predicted_label=pd.DataFrame({'Actual data':y_test,"Predicted data":y_pred4})
Predicted_label
# Out:
#        Actual data  Predicted data
# 37325            1               1
# 33133            1               1
# 1540             0               0
# 1674             0               0
# 22048            0               0
# ...            ...             ...
# 16177            0               0
# 40823            1               1
# 1123             0               0
# 19167            0               0
# 13427            0               0
#
# [13470 rows x 2 columns]

# %% [markdown]
# # ..............................................THANK YOU......................................................
